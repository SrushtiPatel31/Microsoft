# %%
import numpy as np

# %%
np.add(1,1)
# Out:
# np.int64(2)

# %%
numbers = np.array([1,2,3,4,5])
print(type(numbers))
# Out:
# <class 'numpy.ndarray'>

# %%
numbers.shape
# Out:
# (5,)

# %%
numbers[2]
# Out:
# np.int64(3)

# %%
dim = np.array([[1,2,3,4],[5,6,2,3]])
dim.shape
# Out:
# (2, 4)

# %%
print(dim)
# Out:
# [[1 2 3 4]
#  [5 6 2 3]]

# %%
print(dim[0][2])
# Out:
# 3

# %%
np.zeros([2,3])
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.full([2,3],6)
# Out:
# array([[6, 6, 6],
#        [6, 6, 6]])

# %%
a = np.array([[[[1,2,3,4]]]])
a.shape
# Out:
# (1, 1, 1, 4)

# %%
a = np.array([1,2,3,4,5,6,7])

# %%
# Slicing
print(a[2:6])
print(a[-5:-1])
print(a[1:3:3])
# Out:
# [3 4 5 6]
# [3 4 5 6]
# [2]

# %%
d = np.array([[1,2,3,4],[5,6,2,3]])
print(d[1,1:4])
# Out:
# [6 2 3]

# %%
# Reshaping
b = np.array([1,5,2,8,5,9,3,5,0,4])
b.reshape([2,5])
# Out:
# array([[1, 5, 2, 8, 5],
#        [9, 3, 5, 0, 4]])

# %%
c = np.array([[1, 5, 2, 8, 5],[9, 3, 5, 0, 4]])
c.reshape(1,10)
# Out:
# array([[1, 5, 2, 8, 5, 9, 3, 5, 0, 4]])

# %%
arr = np.array([[1, 5, 2, 8, 5],[9, 3, 5, 0, 4]])
newarr = arr.reshape(-1)
print(newarr)
# Out:
# [1 5 2 8 5 9 3 5 0 4]

# %%
from numpy import random
random = np.random.randint(10,size=4)
print(random)
# Out:
# [4 0 6 0]

# %%
from numpy import random

x = random.choice([1,3,3,6],size=(1,4))
print(x)
# Out:
# [[3 1 3 6]]

# %%
import matplotlib.pyplot as plt 

x = np.array([0,6])
y = np.array([0,255])

#plt.plot(x,y,marker = 'o',linestyle = '--',color = 'black')
plt.plot(x,y,"*:g")
plt.title('Linear Data')
plt.xlabel('Product')
plt.ylabel('Price')
plt.show()

# %%
x = np.array([4,5,3,6,8,3,8,8,4,8,2,4,1])
y = np.array([6,3,5,4,7,4,0,7,5,6,9,7,1])
plt.scatter(x,y)

x = np.array([4,5,2,6,5,3,8,4,4,8,2,4,1])
y = np.array([6,3,4,4,7,8,0,7,6,6,9,7,1])
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt 
import numpy as np

#plot-1
x = np.array([2,5,4,7])
y = np.array([3,7,1,9])
plt.subplot(1,2,1)
plt.plot(x,y)

#plot-2
x = np.array([2,4,8,7])
y = np.array([8,7,2,9])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
x = np.array(["A","B","C","D"])
y = np.array([3,1,3,6])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

x = np.array([78,45,25,88])
plt.pie(x)
plt.show()
